# %%
import seaborn as sns

plt.figure(figsize=(10,8))

sns.heatmap(
    df.select_dtypes(include="number").corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Conclusion
#
# This project analyzed Tamil Nadu road accident data from 2020 and 2021.
#
# Major findings:
#
# - Chennai City recorded the highest number of accidents.
# - Cuddalore and Villupuram also showed high accident rates.
# - Fatal accidents are strongly correlated with total accidents.
# - Two-wheelers and lorries contribute significantly to accident deaths.
# - Data visualization helped identify accident-prone districts.
#
# This analysis can help authorities focus road safety measures on high-risk districts.

# %%
top_fatal = df.sort_values("2021_fatal", ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top_fatal["district"], top_fatal["2021_fatal"])

plt.title("Top 10 Fatal Accident Districts")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Key Insights
#
# 1. Chennai City recorded the highest number of accidents in 2021.
# 2. Cuddalore and Villupuram are among the top accident-prone districts.
# 3. Fatal accidents show a strong relationship with total accidents.
# 4. Two-wheelers and lorries contribute significantly to accident deaths.
# 5. Some districts consistently show high accident rates across years.

# %%
death_cols = [
    "death_by_lorries__2021",
    "death_by_buses2021",
    "death_by_carsjeeps_2021",
    "death_by_threewheelers__2021",
    "death_by_twowheelers_2021",
    "death_by_others_2021"
]

df[death_cols].sum().plot(kind="bar")

plt.title("Deaths by Vehicle Type (2021)")
plt.ylabel("Deaths")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Conclusion
#
# This analysis identified accident-prone districts in Tamil Nadu and compared accident trends between 2020 and 2021.
#
# The findings indicate that Chennai City recorded the highest number of accidents, followed by districts such as Cuddalore and Villupuram. The study also highlights the relationship between fatal accidents and total accidents, helping authorities focus on road safety improvements in high-risk areas.

# %%
danger = df.loc[df["total__2021"].idxmax()]

print("Most Dangerous District:")
print(danger["district"])
# Out:
# Most Dangerous District:
# Chennai City

# %%
top10 = df.sort_values("total__2021", ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top10["district"], top10["total__2021"])

plt.xticks(rotation=45)
plt.title("Top 10 Districts by Accidents in 2021")

plt.show()

# %%
import matplotlib.pyplot as plt

fatal_2020 = df["2020_fatal"].sum()
fatal_2021 = df["2021_fatal"].sum()

plt.bar(["2020", "2021"], [fatal_2020, fatal_2021])

plt.title("Fatal Accidents Comparison")
plt.ylabel("Number of Fatal Accidents")

plt.show()

# %%
df.describe()
# Out:
#              _id        sno  2020_fatal  2021_fatal  2020_nonfatal  \
# count  43.000000  43.000000   43.000000   43.000000      43.000000
# mean   22.000000  22.000000  322.488372  342.930233     836.604651
# std    12.556539  12.556539  177.078187  182.425118     572.095611
# min     1.000000   1.000000   26.000000   32.000000     132.000000
# 25%    11.500000  11.500000  185.500000  222.500000     519.500000
# 50%    22.000000  22.000000  293.000000  318.000000     656.000000
# 75%    32.500000  32.500000  446.000000  492.000000    1046.500000
# max    43.000000  43.000000  885.000000  975.000000    3502.000000
#
#        2021_nonfatal  total__2020  total__2021  death_by_lorries__2021  \
# count      43.000000    43.000000    43.000000               43.000000
# mean      951.976744  1159.093023  1294.906977               50.953488
# std       647.687626   732.302657   812.856393               32.896630
# min       178.000000   158.000000   210.000000                1.000000
# ...

# %%
top10 = df.sort_values("total__2021", ascending=False).head(10)

print(top10[["district", "total__2021"]])
# Out:
#         district  total__2021
# 0   Chennai City         5034
# 10     Cuddalore         2927
# 41    Villupuram         2131
# 38       Tirupur         2061
# 9     Coimbatore         1926
# 26         Salem         1922
# 13         Erode         1852
# 29     Thanjavur         1849
# 12      Dindigul         1747
# 18   Krishnagiri         1734

# %%
df.columns
# Out:
# Index(['_id', 'sno', 'district', '2020_fatal', '2021_fatal', '2020_nonfatal',
#        '2021_nonfatal', 'total__2020', 'total__2021', 'death_by_lorries__2021',
#        'death_by_buses2021', 'death_by_carsjeeps_2021',
#        'death_by_threewheelers__2021', 'death_by_twowheelers_2021',
#        'death_by_others_2021', 'total_accidents', 'latitude', 'longitude'],
#       dtype='str')

# %%
print("Rows, Columns:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nStatistics:")
print(df.describe())
# Out:
# Rows, Columns: (43, 18)
#
# Missing Values:
# _id                             0
# sno                             0
# district                        0
# 2020_fatal                      0
# 2021_fatal                      0
# 2020_nonfatal                   0
# 2021_nonfatal                   0
# total__2020                     0
# total__2021                     0
# death_by_lorries__2021          0
# death_by_buses2021              0
# death_by_carsjeeps_2021         0
# death_by_threewheelers__2021    0
# death_by_twowheelers_2021       0
# death_by_others_2021            0
# total_accidents                 0
# latitude                        0
# longitude                       0
# dtype: int64
#
# Statistics:
#              _id        sno  2020_fatal  2021_fatal  2020_nonfatal  \
# count  43.000000  43.000000   43.000000   43.000000      43.000000
# mean   22.000000  22.000000  322.488372  342.930233     836.604651
# ...

# %%
for col in df.columns:
    print(repr(col))
# Out:
# '_id'
# 'sno'
# 'district'
# '2020_fatal'
# '2021_fatal'
# '2020_nonfatal'
# '2021_nonfatal'
# 'total__2020'
# 'total__2021'
# 'death_by_lorries__2021'
# 'death_by_buses2021'
# 'death_by_carsjeeps_2021'
# 'death_by_threewheelers__2021'
# 'death_by_twowheelers_2021'
# 'death_by_others_2021'
# 'total_accidents'
# 'latitude'
# 'longitude'

# %%
for col in df.columns:
    print(col)
# Out:
# _id
# sno
# district
# 2020_fatal
# 2021_fatal
# 2020_nonfatal
# 2021_nonfatal
# total__2020
# total__2021
# death_by_lorries__2021
# death_by_buses2021
# death_by_carsjeeps_2021
# death_by_threewheelers__2021
# death_by_twowheelers_2021
# death_by_others_2021
# total_accidents
# latitude
# longitude

# %%
import matplotlib.pyplot as plt

top5 = df.sort_values("total__2021", ascending=False).head(5)

plt.figure(figsize=(8,5))
plt.bar(top5["district"], top5["total__2021"])
plt.xticks(rotation=45)
plt.title("Top 5 Districts by Accidents in 2021")
plt.show()

# %%
import matplotlib.pyplot as plt

top5 = df.sort_values("total_2021", ascending=False).head(5)

plt.figure(figsize=(8,5))
plt.bar(top5["district"], top5["total_2021"])
plt.xticks(rotation=45)
plt.title("Top 5 Districts by Accidents in 2021")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 top5 = df.sort_values("total_2021", ascending=False).head(5)
#       4
#       5 plt.figure(figsize=(8,5))
#       6 plt.bar(top5["district"], top5["total_2021"])
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:8359, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8355             )
#    8356         elif by:
#    8357             # len(by) == 1
#    8358
# -> 8359             k = self._get_label_or_level_values(by[0], axis=axis)
#    8360
#    8361             # need to rewrap column in Series to apply key function
#    8362             if key is not None:
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['_id', 'sno', 'district', '2020_fatal', '2021_fatal', '2020_nonfatal', '2021_nonfatal', 'total__2020', 'total__2021', 'death_by_lorries__2021', 'death_by_buses2021', 'death_by_carsjeeps_2021', 'death_by_threewheelers__2021', 'death_by_twowheelers_2021', 'death_by_others_2021', 'total_accidents', 'latitude', 'longitude']

# %%
import pandas as pd

df = pd.read_csv("updated_dataset.csv")

df.head()
# Out:
#    _id  sno              district  2020_fatal  2021_fatal  2020_nonfatal  \
# 0    1  1.0          Chennai City         885         975           3502
# 1    2  2.0       Coimbatore City         187         232            520
# 2    3  3.0          Madurai City         158         152            372
# 3    4  4.0            Salem City         151         147            473
# 4    5  5.0  Tiruchirappalli City         127         126            271
#
#    2021_nonfatal  total__2020  total__2021  death_by_lorries__2021  \
# 0           4059         4387         5034                     156
# 1            634          707          866                      34
# 2            466          530          618                      12
# 3            537          624          684                      28
# 4            273          398          399                      13
#
#    death_by_buses2021  death_by_carsjeeps_2021  death_by_threewheelers__2021  \
# ...

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.11.0

# %%
import matplotlib.pyplot as plt

top5 = df.sort_values("total_2021", ascending=False).head(5)

plt.figure(figsize=(8,5))
plt.bar(top5["district"], top5["total_2021"])
plt.xticks(rotation=45)
plt.title("Top 5 Districts by Accidents in 2021")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 top5 = df.sort_values("total_2021", ascending=False).head(5)
#       4
#       5 plt.figure(figsize=(8,5))
#       6 plt.bar(top5["district"], top5["total_2021"])
#
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:8359, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8355             )
#    8356         elif by:
#    8357             # len(by) == 1
#    8358
# -> 8359             k = self._get_label_or_level_values(by[0], axis=axis)
#    8360
#    8361             # need to rewrap column in Series to apply key function
#    8362             if key is not None:
#
# ...

# %%
df.describe()
# Out:
#              _id        sno  2020_fatal  2021_fatal  2020_nonfatal  \
# count  43.000000  43.000000   43.000000   43.000000      43.000000
# mean   22.000000  22.000000  322.488372  342.930233     836.604651
# std    12.556539  12.556539  177.078187  182.425118     572.095611
# min     1.000000   1.000000   26.000000   32.000000     132.000000
# 25%    11.500000  11.500000  185.500000  222.500000     519.500000
# 50%    22.000000  22.000000  293.000000  318.000000     656.000000
# 75%    32.500000  32.500000  446.000000  492.000000    1046.500000
# max    43.000000  43.000000  885.000000  975.000000    3502.000000
#
#        2021_nonfatal  total__2020  total__2021  death_by_lorries__2021  \
# count      43.000000    43.000000    43.000000               43.000000
# mean      951.976744  1159.093023  1294.906977               50.953488
# std       647.687626   732.302657   812.856393               32.896630
# min       178.000000   158.000000   210.000000                1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _id                           43 non-null     int64
#  1   sno                           43 non-null     float64
#  2   district                      43 non-null     str
#  3   2020_fatal                    43 non-null     int64
#  4   2021_fatal                    43 non-null     int64
#  5   2020_nonfatal                 43 non-null     int64
#  6   2021_nonfatal                 43 non-null     int64
#  7   total__2020                   43 non-null     int64
#  8   total__2021                   43 non-null     int64
#  9   death_by_lorries__2021        43 non-null     int64
#  10  death_by_buses2021            43 non-null     int64
#  11  death_by_carsjeeps_2021       43 non-null     int64
#  12  death_by_threewheelers__2021  43 non-null     int64
# ...

# %%
df = pd.read_csv("updated_dataset.csv")
df.head()
# Out:
#    _id  sno              district  2020_fatal  2021_fatal  2020_nonfatal  \
# 0    1  1.0          Chennai City         885         975           3502
# 1    2  2.0       Coimbatore City         187         232            520
# 2    3  3.0          Madurai City         158         152            372
# 3    4  4.0            Salem City         151         147            473
# 4    5  5.0  Tiruchirappalli City         127         126            271
#
#    2021_nonfatal  total__2020  total__2021  death_by_lorries__2021  \
# 0           4059         4387         5034                     156
# 1            634          707          866                      34
# 2            466          530          618                      12
# 3            537          624          684                      28
# 4            273          398          399                      13
#
#    death_by_buses2021  death_by_carsjeeps_2021  death_by_threewheelers__2021  \
# ...

# %%
import pandas as pd

df = pd.read_csv("updated_dataset.csv")

df.head()
# Out:
#    _id  sno              district  2020_fatal  2021_fatal  2020_nonfatal  \
# 0    1  1.0          Chennai City         885         975           3502
# 1    2  2.0       Coimbatore City         187         232            520
# 2    3  3.0          Madurai City         158         152            372
# 3    4  4.0            Salem City         151         147            473
# 4    5  5.0  Tiruchirappalli City         127         126            271
#
#    2021_nonfatal  total__2020  total__2021  death_by_lorries__2021  \
# 0           4059         4387         5034                     156
# 1            634          707          866                      34
# 2            466          530          618                      12
# 3            537          624          684                      28
# 4            273          398          399                      13
#
#    death_by_buses2021  death_by_carsjeeps_2021  death_by_threewheelers__2021  \
# ...
